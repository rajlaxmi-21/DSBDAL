# %% [raw]
# num - num -> scattere, line
# num - cat -> bar, box, dist
# cat - cat -> heatmap, clustermap
#
# cat -> countplot
# num -> hist, kde, dist

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(x=df['age'], y=df['fare'], hue=df['class'])
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.countplot(x=df['survived'], hue=df['class'])
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
## higher fare -> more priority

# %%
sns.barplot(x=df['class'], y=df['fare'])
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [raw]
# fare was higher for 1st class

# %%
sns.countplot(x=df['survived'], hue=df['sex'])
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.histplot(data=df, x='age', hue='sex', multiple='stack', bins=30, kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.jointplot(x=df['age'], y=df['fare'], hue=df['survived'])

# %%
sns.barplot(x=df['sex'], y=df['survived'])
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.countplot(x=df['sex'], hue=df['survived'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df.value_counts('sex')
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[df['survived']==1].value_counts('sex')
# Out:
# sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
109/577
# Out:
# 0.18890814558058924

# %%
233/314
# Out:
# 0.7420382165605095

# %%
sns.histplot(x=df['fare'], bins=30, kde=True)
plt.xlabel('fare')
plt.ylabel('no. of pass')
# Out:
# Text(0, 0.5, 'no. of pass')

# %%
sns.pairplot(df)
